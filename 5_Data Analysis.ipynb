# %% [markdown]
# # Analysis the Data

# %% [markdown]
# ## Merging & Joining Data

# %%
import pandas as pd

# %%
df1 = pd.read_csv('1_health_supplement.csv')  #data page 1

# %%
df1
# Out:
#                                           Product Name Discount Prices(?)  \
# 0    Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1       BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2    NutraEats Protein Plus Supplement Whey Protein...                459
# 3    NutraEats Protein Plus Supplement Whey Protein...                489
# 4    NutraEats Protein Plus Supplement Whey Protein...                528
# ..                                                 ...                ...
# 270  Dr. Morepen LightLife On-The-Go Meal |19g Prot...                623
# 271  POWERLIFT for Muscle Mass Gain with Shaker, Hi...                759
# 272  PATANJALI Nutrela Slim choice, 500 Gm Whey Pro...              1,083
# 273  Labrada nutrition Super Mass Gainer 3kg |(Dulc...              2,564
# 274  Primemuscle Nutritions Creatine monohydrate wi...                225
#
#     Actual Prices(?)              Weight/Type Discount Percentage(%)  Rating  \
# ...

# %%
df2 = pd.read_csv('2_health_supplement.csv') #data page 2

# %%
df2
# Out:
#                                           Product Name Discount Prices(?)  \
# 0    Kapiva Himalayan Shilajit Resin|Rich in Fulvic...                463
# 1    Kapiva Shilajit Gold | Contains 24 Carat Gold ...                899
# 2    Baidyanath Giloy Juice 1 Litre, Natural Immuni...                195
# 3    Multani Chyawanprash Special Enriched With Kes...                266
# 4    Dr Vitasta ayurvedic medicine for weight gain,...                330
# ..                                                 ...                ...
# 805  Hakeem Baqai's Night Safari 40 Pills (Each 80 ...                263
# 806  Kapiva Himalayan Shilajit Resin|Rich in Fulvic...                359
# 807  Kapiva Shilajit Gold | Contains 24 Carat Gold ...              1,048
# 808  fazeelat creations KASHMIRI AYURVEDIC SHILAJIT...              1,525
# 809  ALPHA AYURVEDA Sakhi Tone - Ayurvedic Weight G...                198
#
#     Actual Prices(?)             Weight/Type Discount Percentage(%)  Rating  \
# ...

# %%
df3 = pd.read_csv('3_health_supplement.csv') #data page 3

# %%
df3
# Out:
#                                           Product Name Discount Prices(?)  \
# 0    deconstruct Sunscreen - SPF 55+ PA+++ Lightwei...                314
# 1                Cetaphil Oily Skin Cleanser Face Wash                608
# 2    BIOTIQUE Rice Water & Niacinamide Gel |Removes...                165
# 3    TRU HAIR & SKIN Radiant Glow Skincare Trio: Vi...                415
# 4    Skinkraft Vitamin C Radiance Kit, Face Wash + ...              1,399
# ..                                                 ...                ...
# 782  GLAMVEDA Glass Skin Rice Ceramide Facewash+Soa...                225
# 783  Cosrx BHA Blackhead Power Liquid Exfoliant | B...                226
# 784  Organic Netra Rose Water Toner With Vitamin C,...                464
# 785  JEEVIKA HERBS MANGO SEEDS POWDER , MANGO GUTHL...                799
# 786  HipHop Skincare Charcoal Nose Strips (Men) - B...                496
#
#     Actual Prices(?)         Weight/Type Discount Percentage(%)  Rating  \
# ...

# %%
df4 = pd.read_csv('4_health_supplement.csv')  #data page 4

# %%
df4
# Out:
#                                           Product Name Discount Prices(?)  \
# 0    Cetaphil DAM DAILY ADVANCE ULTRA HYDRATING LOTION                237
# 1          Parachute Advansed Deep Nourish Body Lotion                323
# 2    BELLAVITA DATE WOMAN Perfume Body Lotion|Helps...                225
# 3    Joy Relaxing Green Tea Body Serum Lotion | Ref...                174
# 4    Santoor Body Lotion for Extra Moisturising Wit...                180
# ..                                                 ...                ...
# 907  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 908   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 909  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 910  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 911   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
#     Actual Prices(?) Weight/Type Discount Percentage(%)  Rating     Users
# ...

# %%
df5 = pd.concat([df1,df2,df3,df4])   #concat all data page (1,2,3,4) in 5 all data in here

# %%
df5   #it is the final data upgrade ,onward what we perform operation by using this data
# Out:
#                                           Product Name Discount Prices(?)  \
# 0    Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1       BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2    NutraEats Protein Plus Supplement Whey Protein...                459
# 3    NutraEats Protein Plus Supplement Whey Protein...                489
# 4    NutraEats Protein Plus Supplement Whey Protein...                528
# ..                                                 ...                ...
# 907  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 908   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 909  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 910  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 911   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
#     Actual Prices(?)              Weight/Type Discount Percentage(%)  Rating  \
# ...

# %%
df5.to_csv('5_total_health_supplement.csv',index=False)   #push our final data(df5) to a csv file

# %% [markdown]
# ## Exploring the Data with Analysis

# %%
df = pd.read_csv('total_health_supplement.csv')

# %%
df.head()   #it give first 5 rows
# Out:
#                                         Product Name Discount Prices(?)  \
# 0  Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1     BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2  NutraEats Protein Plus Supplement Whey Protein...                459
# 3  NutraEats Protein Plus Supplement Whey Protein...                489
# 4  NutraEats Protein Plus Supplement Whey Protein...                528
#
#   Actual Prices(?)              Weight/Type Discount Percentage(%)  Rating  \
# 0              749    122 g, Tropical Tango                20% off     4.3
# 1            2,899  1 kg, Belgian Chocolate                48% off     4.1
# 2              599         200 g, Chocolate                23% off     4.3
# 3              899         300 g, Chocolate                45% off     4.3
# 4              799         250 g, Chocolate                33% off     4.2
#
#       Users
# 0  2,51,934
# 1    99,351
# 2  2,51,934
# 3  2,51,934
# 4     1,467

# %%
df.tail()  #iit gives last 5 rows
# Out:
#                                            Product Name Discount Prices(?)  \
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
#      Actual Prices(?) Weight/Type Discount Percentage(%)  Rating   Users
# 2779              499      400 ml                85% off     4.4  20,469
# 2780              300      150 ml                55% off     3.9      17
# 2781              525         1 L                22% off     4.1   1,167
# 2782               80      800 ml                24% off     4.6     269
# 2783              585      400 ml                 8% off     4.6     860

# %%
df.describe()   #describe the data
# Out:
#             Rating
# count  2784.000000
# mean      4.236458
# std       0.262913
# min       1.000000
# 25%       4.100000
# 50%       4.300000
# 75%       4.400000
# max       5.000000

# %%
df.info()   #all about information data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2784 entries, 0 to 2783
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product Name            2784 non-null   object
#  1   Discount Prices(?)      2784 non-null   object
#  2   Actual Prices(?)        2784 non-null   object
#  3   Weight/Type             2784 non-null   object
#  4   Discount Percentage(%)  2784 non-null   object
#  5   Rating                  2784 non-null   float64
#  6   Users                   2784 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 152.4+ KB

# %%
df.columns   #all columns name
# Out:
# Index(['Product Name', 'Discount Prices(?)', 'Actual Prices(?)', 'Weight/Type',
#        'Discount Percentage(%)', 'Rating', 'Users'],
#       dtype='object')

# %%
df.shape   #(rews,columns)
# Out:
# (2784, 7)

# %% [markdown]
# ## Data Selection and Filtering

# %%
df
# Out:
#                                            Product Name Discount Prices(?)  \
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2     NutraEats Protein Plus Supplement Whey Protein...                459
# 3     NutraEats Protein Plus Supplement Whey Protein...                489
# 4     NutraEats Protein Plus Supplement Whey Protein...                528
# ...                                                 ...                ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
# ...

# %%
#accesing only ono columns
df['Product Name']
# Out:
# 0       Wellcore Micronised Creatine Monohydrate | Lab...
# 1          BIGMUSCLES NUTRITION Premium Gold Whey Protein
# 2       NutraEats Protein Plus Supplement Whey Protein...
# 3       NutraEats Protein Plus Supplement Whey Protein...
# 4       NutraEats Protein Plus Supplement Whey Protein...
#                               ...
# 2779    Vaseline Healthy Bright Sun+Pollution Protecti...
# 2780     efatop NEXT Lotion 150ml For Intense Moisturizer
# 2781    Rubz Cherry Blossom Body Milk with Cherry Blos...
# 2782    Parachute Advansed Advansed Soft Touch Body Lo...
# 2783     POND's Niacinamide Nourishing Body Lotion 400 ml
# Name: Product Name, Length: 2784, dtype: object

# %%
#access one cloumn with periticular index
df['Product Name'][3]
# Out:
# 'NutraEats Protein Plus Supplement Whey Protein Powder C...'

# %%
type(df['Product Name'])
#giving the type of data
# Out:
# pandas.core.series.Series

# %%
#acessing 2 columns
df[['Product Name','Discount Prices(?)']]
# Out:
#                                            Product Name Discount Prices(?)
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2     NutraEats Protein Plus Supplement Whey Protein...                459
# 3     NutraEats Protein Plus Supplement Whey Protein...                489
# 4     NutraEats Protein Plus Supplement Whey Protein...                528
# ...                                                 ...                ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
# [2784 rows x 2 columns]

# %%
df.loc[1]   #give all about data of index location 1
# Out:
# Product Name              BIGMUSCLES NUTRITION Premium Gold Whey Protein
# Discount Prices(?)                                                 1,499
# Actual Prices(?)                                                   2,899
# Weight/Type                                      1 kg, Belgian Chocolate
# Discount Percentage(%)                                           48% off
# Rating                                                               4.1
# Users                                                             99,351
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Product Name              BIGMUSCLES NUTRITION Premium Gold Whey Protein
# Discount Prices(?)                                                 1,499
# Actual Prices(?)                                                   2,899
# Weight/Type                                      1 kg, Belgian Chocolate
# Discount Percentage(%)                                           48% off
# Rating                                                               4.1
# Users                                                             99,351
# Name: 1, dtype: object

# %%
df.loc[4,'Discount Percentage(%)']   #here we said like give the data  index 7 on discount columns
# Out:
# '33% off'

# %%
#by using iloc we access data by using only index number
df.iloc[4,4]   #4 index ,#4 stand for column with index wise
# Out:
# '33% off'

# %%
df.loc[0:3,['Discount Percentage(%)','Product Name']]   #said like give data of index from 0 to 3 of column Discount Percentage(%)','Product Name
# Out:
#   Discount Percentage(%)                                       Product Name
# 0                20% off  Wellcore Micronised Creatine Monohydrate | Lab...
# 1                48% off     BIGMUSCLES NUTRITION Premium Gold Whey Protein
# 2                23% off  NutraEats Protein Plus Supplement Whey Protein...
# 3                45% off  NutraEats Protein Plus Supplement Whey Protein...

# %%
df.iloc[0:,0:3]   #by acess by using index value by giveind row index columns index
# Out:
#                                            Product Name Discount Prices(?)  \
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein              1,499
# 2     NutraEats Protein Plus Supplement Whey Protein...                459
# 3     NutraEats Protein Plus Supplement Whey Protein...                489
# 4     NutraEats Protein Plus Supplement Whey Protein...                528
# ...                                                 ...                ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
#      Actual Prices(?)
# 0                 749
# ...

# %%
#we want the like give data which rating is grater than 4.5
df[df['Rating']>4.5]
# Out:
#                                            Product Name Discount Prices(?)  \
# 86    Wellcore Micronised Creatine Monohydrate | Lab...                599
# 97    Wellcore Micronised Creatine Monohydrate | Lab...              1,199
# 106   BIGMUSCLES NUTRITION Nitra Isolate | 32g Prote...              1,649
# 117   N2B 100% Whey Gold Protein Supplement Powder W...                762
# 175      GNC Pro Performance Power Protein Whey Protein              3,999
# ...                                                 ...                ...
# 2744  Aveeno Active Naturals Skin Relief Moisturizin...                587
# 2757            NIVEA Shea Smooth ) Deep Moisture Serum                315
# 2776                      DEWSOFT MOISTURIZATION LOTION                277
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                241
#
# ...

# %%
#we want the like give data which rating is grater than 4.5 give that product name only
df[df['Rating']>4.5]['Product Name']
# Out:
# 86      Wellcore Micronised Creatine Monohydrate | Lab...
# 97      Wellcore Micronised Creatine Monohydrate | Lab...
# 106     BIGMUSCLES NUTRITION Nitra Isolate | 32g Prote...
# 117     N2B 100% Whey Gold Protein Supplement Powder W...
# 175        GNC Pro Performance Power Protein Whey Protein
#                               ...
# 2744    Aveeno Active Naturals Skin Relief Moisturizin...
# 2757              NIVEA Shea Smooth ) Deep Moisture Serum
# 2776                        DEWSOFT MOISTURIZATION LOTION
# 2782    Parachute Advansed Advansed Soft Touch Body Lo...
# 2783     POND's Niacinamide Nourishing Body Lotion 400 ml
# Name: Product Name, Length: 220, dtype: object

# %%
#lets use and functions
#here we said like give highest rating product which has 85% Discount Percentage(%)
df[(df['Rating']>4.5)&(df['Discount Percentage(%)']>'85% off')]    #here we probkem becz of in our funtion we str charecter ,undertsand when you use you also take int data.
# Out:
#                                            Product Name Discount Prices(?)  \
# 1145  GLAMVEDA 2% Kojic Acid 3 Step Skincare Set – F...                513
# 1484  voorkoms Acne Scars Cure & Herbal Bath Combo F...                574
# 1588  purobio Buy Daily Face Wash & Get Free Lavende...                910
# 2224     NIVEA Cocoa Nourish Lotion 400 Ml ( Pack Of 1)                414
# 2733  Vaseline Healthy Bright Daily Brightening Body...                270
#
#      Actual Prices(?)         Weight/Type Discount Percentage(%)  Rating Users
# 1145            1,148  3 Items in the set                89% off     4.9    11
# 1484            1,494               100 g                87% off     4.7    24
# 1588              199               100 g                87% off     4.6     7
# 2224              275              400 ml                 9% off     4.6    15
# 2733              649              400 ml                 9% off     4.7    31

# %%
df.query("Users > '100000'").head(1)   #here we said like give data which has greater than 100000 user Users columns ,give fist one columns
# Out:
#                                         Product Name Discount Prices(?)  \
# 0  Wellcore Micronised Creatine Monohydrate | Lab...                599
#
#   Actual Prices(?)            Weight/Type Discount Percentage(%)  Rating  \
# 0              749  122 g, Tropical Tango                20% off     4.3
#
#       Users
# 0  2,51,934

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %%
import pandas as pd
df = pd.read_csv('total_health_supplement.csv')

# %%
#lets check which are column are interger or string
df.dtypes
#shit all value which containis number data that store in number format
# Out:
# Product Name               object
# Discount Prices(?)         object
# Actual Prices(?)           object
# Weight/Type                object
# Discount Percentage(%)     object
# Rating                    float64
# Users                      object
# dtype: object

# %%
# Detect Which Values Are Not Proper Numbers
import pandas as pd

# Assuming df is already loaded
cols_to_check = ['Discount Prices(?)', 'Actual Prices(?)', 'Discount Percentage(%)', 'Users']

for col in cols_to_check:
    print(f"\nChecking column: {col}")
    invalid_rows = df[col].apply(lambda x: pd.to_numeric(str(x).replace(",", "").replace("% off", "").strip(), errors='coerce')).isna()
    if invalid_rows.any():
        print(f"Non-numeric values found in column '{col}':")
        print(df.loc[invalid_rows, col])
    else:
        print("All values are numeric (after cleaning).")
# Out:
# Checking column: Discount Prices(?)
# All values are numeric (after cleaning).
#
# Checking column: Actual Prices(?)
# All values are numeric (after cleaning).
#
# Checking column: Discount Percentage(%)
# All values are numeric (after cleaning).
#
# Checking column: Users
# All values are numeric (after cleaning).

# %%
#Convert to Numeric After Cleaning
df['Discount Prices(?)'] = pd.to_numeric(df['Discount Prices(?)'].str.replace(",", "").str.strip(), errors='coerce')
df['Actual Prices(?)'] = pd.to_numeric(df['Actual Prices(?)'].str.replace(",", "").str.strip(), errors='coerce')

# Remove '% off' and convert to numeric
df['Discount Percentage(%)'] = df['Discount Percentage(%)'].str.replace('% off', '').str.strip()
df['Discount Percentage(%)'] = pd.to_numeric(df['Discount Percentage(%)'], errors='coerce')

# Remove commas in Users and convert to integer
df['Users'] = df['Users'].str.replace(",", "").str.strip()
df['Users'] = pd.to_numeric(df['Users'], errors='coerce').astype("Int64")  # Keeps NaN support

# %%
df
# Out:
#                                            Product Name  Discount Prices(?)  \
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                 599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein                1499
# 2     NutraEats Protein Plus Supplement Whey Protein...                 459
# 3     NutraEats Protein Plus Supplement Whey Protein...                 489
# 4     NutraEats Protein Plus Supplement Whey Protein...                 528
# ...                                                 ...                 ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                 593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                 569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                 353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                 349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                 241
#
# ...

# %%
#lests check again
print(df.dtypes)
# Out:
# Product Name               object
# Discount Prices(?)          int64
# Actual Prices(?)            int64
# Weight/Type                object
# Discount Percentage(%)      int64
# Rating                    float64
# Users                       Int64
# dtype: object

# %%
#lets check is there is null 
df.isnull()
# Out:
#       Product Name  Discount Prices(?)  Actual Prices(?)  Weight/Type  \
# 0            False               False             False        False
# 1            False               False             False        False
# 2            False               False             False        False
# 3            False               False             False        False
# 4            False               False             False        False
# ...            ...                 ...               ...          ...
# 2779         False               False             False        False
# 2780         False               False             False        False
# 2781         False               False             False        False
# 2782         False               False             False        False
# 2783         False               False             False        False
#
#       Discount Percentage(%)  Rating  Users
# 0                      False   False  False
# ...

# %%
#method-2 it is best way to see is in this data set there is null or what
df.isnull().sum()
#it gives 0 that means  there is no null value
# Out:
# Product Name              0
# Discount Prices(?)        0
# Actual Prices(?)          0
# Weight/Type               0
# Discount Percentage(%)    0
# Rating                    0
# Users                     0
# dtype: int64

# %%
#lets check is there is any duplicated
df.duplicated()
#it gives false there is no duplicate
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2779    False
# 2780    False
# 2781    False
# 2782    False
# 2783    False
# Length: 2784, dtype: bool

# %% [markdown]
# ## Data Transformation

# %%
df
# Out:
#                                            Product Name  Discount Prices(?)  \
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                 599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein                1499
# 2     NutraEats Protein Plus Supplement Whey Protein...                 459
# 3     NutraEats Protein Plus Supplement Whey Protein...                 489
# 4     NutraEats Protein Plus Supplement Whey Protein...                 528
# ...                                                 ...                 ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                 593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                 569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                 353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                 349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                 241
#
# ...

# %%
#sorting the value of Discount price and Actual price
df.sort_values(['Discount Prices(?)','Actual Prices(?)'])
# Out:
#                                            Product Name  Discount Prices(?)  \
# 2164      Santoor Body Lotion Whitening & UV Protection                  10
# 144   Yogabar 10g Protein Bar Blueberry Blast, Glute...                  46
# 540   aswini Hiran Joint Energy Powder - Energise yo...                  47
# 2364  JOVEES Herbal Honey and Grapes Hand and Body L...                  52
# 1146  ANI'S Premium Quality Rose Water (Gulab Jal) W...                  61
# ...                                                 ...                 ...
# 185   Optimum Nutrition (ON) Gold Standard 100% Prot...                7599
# 191   MUSCLEBLAZE Biozyme Performance Whey Protein P...               10799
# 172   Optimum Nutrition (ON) Gold Standard 100% Prot...               13254
# 238   Optimum Nutrition (ON) Gold Standard 100% Prot...               13254
# 621   G GLOWSIK Karela Jamun Powder | 11 Potent Herb...               14811
#
# ...

# %%
df.describe()
# Out:
#        Discount Prices(?)  Actual Prices(?)  Discount Percentage(%)  \
# count         2784.000000       2784.000000             2784.000000
# mean           538.448276        866.650144               32.414871
# std            730.749290       1120.027817               21.973278
# min             10.000000         50.000000                1.000000
# 25%            239.000000        380.000000               15.000000
# 50%            359.000000        542.500000               27.000000
# 75%            599.000000        950.000000               48.000000
# max          14811.000000      29979.000000               90.000000
#
#             Rating         Users
# count  2784.000000        2784.0
# mean      4.236458  27513.137572
# std       0.262913  67414.688288
# min       1.000000           1.0
# 25%       4.100000         103.0
# 50%       4.300000         964.5
# 75%       4.400000      14167.75
# max       5.000000      398320.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2784 entries, 0 to 2783
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product Name            2784 non-null   object
#  1   Discount Prices(?)      2784 non-null   int64
#  2   Actual Prices(?)        2784 non-null   int64
#  3   Weight/Type             2784 non-null   object
#  4   Discount Percentage(%)  2784 non-null   int64
#  5   Rating                  2784 non-null   float64
#  6   Users                   2784 non-null   Int64
# dtypes: Int64(1), float64(1), int64(3), object(2)
# memory usage: 155.1+ KB

# %%
#we finssh all operation in our data set.now our data set is 100% capable for our Machine Learning
#lets store our clean data set 
df.to_csv('final_health_supplement.csv',index=False)

# %% [markdown]
# we do not want to perform all operation peroform in this data set .bcz of we use Machine Learning Forwards

# %% [markdown]
# in on next section i starting Visualizing Data for our best Understanding

# %% [markdown]
# # Visualzing the Data
