# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_health_supplement.csv')

# %%
df
# Out:
#                                            Product Name  Discount Prices(?)  \
# 0     Wellcore Micronised Creatine Monohydrate | Lab...                 599
# 1        BIGMUSCLES NUTRITION Premium Gold Whey Protein                1499
# 2     NutraEats Protein Plus Supplement Whey Protein...                 459
# 3     NutraEats Protein Plus Supplement Whey Protein...                 489
# 4     NutraEats Protein Plus Supplement Whey Protein...                 528
# ...                                                 ...                 ...
# 2779  Vaseline Healthy Bright Sun+Pollution Protecti...                 593
# 2780   efatop NEXT Lotion 150ml For Intense Moisturizer                 569
# 2781  Rubz Cherry Blossom Body Milk with Cherry Blos...                 353
# 2782  Parachute Advansed Advansed Soft Touch Body Lo...                 349
# 2783   POND's Niacinamide Nourishing Body Lotion 400 ml                 241
#
# ...

# %% [markdown]
# ## Distribution of Discount Percentage

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Discount Percentage(%)'], bins=30, kde=True,color='purple')
plt.title("Distribution of Discount Percentage")
plt.xlabel("Discount (%)")
plt.ylabel("Number of Products")
plt.show()

# %% [markdown]
# ##  Discount vs Rating (Scatter Plot)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Discount Percentage(%)',y='Rating',color='blue',data=df)

plt.xlabel('Discount Percentage')
plt.ylabel('Rating')
plt.title('Discount Vs Rating')
# Out:
# Text(0.5, 1.0, 'Discount Vs Rating')

# %%
x = df.groupby('Discount Prices(?)')['Actual Prices(?)'].mean()

# %%
x
# Out:
# Discount Prices(?)
# 10        375.000000
# 46       1249.000000
# 47        799.000000
# 52        435.000000
# 61       1015.333333
#             ...
# 6947     9999.000000
# 7599      779.000000
# 10799    1999.000000
# 13254    1849.500000
# 14811     798.000000
# Name: Actual Prices(?), Length: 731, dtype: float64

# %% [markdown]
# ## Relation between Discount Price and Actual Price(Bar plot)

# %%
plt.figure(figsize=(10,6))
plt.bar(x.index,x.values,width=70,color='green')
plt.xlabel('Discount Prices')
plt.ylabel('Actual Prices')
plt.title('Relation between Discount Price and Actual Price')
# Out:
# Text(0.5, 1.0, 'Relation between Discount Price and Actual Price')

# %% [markdown]
# ## Relation Between Highest Price And Lowest price in Discount Price
# ## Relation Between Highest Price And Lowest price in Actual Price

# %%
x = df.sort_values('Discount Prices(?)').head()

# %%
x1 = x['Discount Prices(?)']

# %%
y = df.sort_values('Discount Prices(?)').tail()

# %%
y1 = y['Discount Prices(?)']

# %%
a = df.sort_values('Actual Prices(?)').head()

# %%
a1 = a['Actual Prices(?)']

# %%
b = df.sort_values('Actual Prices(?)').tail()

# %%
b1 = b['Actual Prices(?)']

# %%
plt.figure(figsize=(10,6))
plt.style.use('ggplot')
plt.plot(x1,y1,linewidth='2',linestyle="--")
plt.title('Relation Between Highest Price And Lowest price in Discount Price')
# Out:
# Text(0.5, 1.0, 'Relation Between Highest Price And Lowest price in Discount Price')

# %%
plt.figure(figsize=(10,6))
plt.plot(a1,b1,linewidth='2',linestyle="--")
plt.title('Relation Between Highest Price And Lowest price in Actual Price')
# Out:
# Text(0.5, 1.0, 'Relation Between Highest Price And Lowest price in Actual Price')

# %% [markdown]
# ##  Relation Between Rating and Users

# %%
w = df.groupby('Rating')['Users'].mean()

# %%
plt.figure(figsize=(30,6))
sns.displot(x = w.index,y = w.values,color='silver')

# %% [markdown]
# ## Top 5 product Weight And Type

# %%
g = df.sort_values('Discount Prices(?)')

# %%
h = g.tail()

# %%
 j = h['Product Name']

# %%
k = h['Weight/Type']

# %%
sns.histplot(x=k,y=j,color='gold')
plt.xticks(rotation=45)  # or rotation=90 for vertical labels
#plt.tight_layout()
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, '2.27 kg, Cookies & Cream'),
#   Text(1, 0, '4 kg, Rich Chocolate'),
#   Text(2, 0, '4 kg, Vanilla Ice Cream'),
#   Text(3, 0, '200 g')])

# %% [markdown]
# ## Top  highest Rating product Vs Top Lowest Rating product

# %%
n = df.sort_values('Rating')

# %%
m = n.head(1)

# %%
o = n.tail(1)

# %%
c = pd.concat([m,o])

# %%
c
# Out:
#                                            Product Name  Discount Prices(?)  \
# 1707  Tikitoro Teens Anti-Acne Care Kit with Face Wa...                 270
# 879   Kerala Ayurveda Sahacharadi Thailam For Back P...                1476
#
#       Actual Prices(?) Weight/Type  Discount Percentage(%)  Rating  Users
# 1707               349      150 ml                       5     1.0      3
# 879                370      200 ml                      15     5.0      4

# %%
z = c['Product Name']

# %%
z
# Out:
# 1707    Tikitoro Teens Anti-Acne Care Kit with Face Wa...
# 879     Kerala Ayurveda Sahacharadi Thailam For Back P...
# Name: Product Name, dtype: object

# %%
k = c['Rating']

# %%
k
# Out:
# 1707    1.0
# 879     5.0
# Name: Rating, dtype: float64

# %%
colors=['red','green']

# %%
explode=[0.1,0]
plt.pie(k,labels=z,colors=colors,startangle=90,autopct='%1.1f%%',explode=explode,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f0b114e720>,
# ...
#  [Text(-0.6000000162166297, 1.0392304751786507, 'Tikitoro Teens Anti-Acne Care Kit with Face Wash, Gel M...'),
#   Text(0.5499999702695115, -0.9526279613277875, 'Kerala Ayurveda Sahacharadi Thailam For Back Pain Relie...')],
#  [Text(-0.3500000094597006, 0.6062177771875461, '16.7%'),
#   Text(0.2999999837833699, -0.5196152516333385, '83.3%')])

# %% [markdown]
# ## Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Only use numeric columns
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="crest", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()

# %% [markdown]
# ## Discount Percentage over Discount Price based on Rating

# %%
plt.figure(figsize=(20,10))
df.plot(kind='scatter',x='Rating',y='Actual Prices(?)',grid=True,cmap='jet',c='Discount Percentage(%)')
# Out:
# <Axes: xlabel='Rating', ylabel='Actual Prices(?)'>

# %% [markdown]
# ## Correlation  Between Discount Prices(?),Rating,Users

# %%
from pandas.plotting import scatter_matrix
attributes = ['Discount Prices(?)','Rating','Users']
scatter_matrix(df[attributes],figsize=(12,8))
# Out:
# array([[<Axes: xlabel='Discount Prices(?)', ylabel='Discount Prices(?)'>,
#         <Axes: xlabel='Rating', ylabel='Discount Prices(?)'>,
#         <Axes: xlabel='Users', ylabel='Discount Prices(?)'>],
#        [<Axes: xlabel='Discount Prices(?)', ylabel='Rating'>,
#         <Axes: xlabel='Rating', ylabel='Rating'>,
#         <Axes: xlabel='Users', ylabel='Rating'>],
#        [<Axes: xlabel='Discount Prices(?)', ylabel='Users'>,
#         <Axes: xlabel='Rating', ylabel='Users'>,
#         <Axes: xlabel='Users', ylabel='Users'>]], dtype=object)

# %% [markdown]
# ## Total Visual

# %%
df.hist(bins=50,figsize=(14,14),color='purple')
plt.tight_layout()
